# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('darkgrid')
import pandas as pd
# sns.set_palette('Blues')

# %%
tips=sns.load_dataset("tips")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null category
# smoker        244 non-null category
# day           244 non-null category
# time          244 non-null category
# size          244 non-null int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.3 KB

# %%
# Regression Plots

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex', palette='Set1')

# %%
sns.residplot(x='total_bill',y='tip',data=tips, color='indianred')

# %%
auto=pd.read_csv("auto-mpg.csv")
auto
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
# plotting regression plots

# %%
sns.lmplot(x='weight',y='mpg',data=auto,row='cylinders')

# %%
sns.relplot(x='weight',y='mpg',data=auto, kind='scatter')

# %%
sns.regplot(x='weight', y='mpg', data=auto, color='blue', scatter=None, label='First Order')

# %% [markdown]
# # Higher Order Regressions

# %%
# Generate a scatter plot of 'weight' and 'mpg' using red circles
plt.scatter(auto['weight'], auto['mpg'], label='data', color='red', marker='o')

# Plot in blue a linear regression of order 1 between 'weight' and 'mpg'
sns.regplot(x='weight', y='mpg', data=auto, color='blue', scatter=None, label='First Order')

# Plot in green a linear regression of order 2 between 'weight' and 'mpg'
sns.regplot(x='weight', y='mpg', data=auto, color='green', scatter=None, label='Second Order',order=2)

# Add a legend and display the plot
plt.legend(loc='upper right')
plt.show()

# %%
# Group Linear Regressions by row or column

# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
auto=pd.read_csv("auto-mpg.csv",na_values='?')
auto
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
# mpg             398 non-null float64
# cylinders       398 non-null int64
# displacement    398 non-null float64
# horsepower      392 non-null float64
# weight          398 non-null int64
# acceleration    398 non-null float64
# model year      398 non-null int64
# origin          398 non-null int64
# car name        398 non-null object
# dtypes: float64(4), int64(4), object(1)
# memory usage: 28.1+ KB

# %%
auto['origin'] = auto.origin.astype('category')

# %% [markdown]
# We can see that the horsepower column is object or string

# %%
sns.lmplot(x='weight',y='horsepower',data=auto,hue='origin')

# %%
sns.lmplot(x='weight',y='horsepower',data=auto,row='origin')

# %% [markdown]
# # Visualizing Univariate Distributions

# %% [markdown]
# * Strip Plots
# * Swarm Plots
# * Violin Plots

# %%
import pandas as pd 
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
auto=pd.read_csv("auto-mpg.csv", na_values='?')
auto
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %% [markdown]
# ### Strip Plot

# %%
# Make a strip plot of 'hp' grouped by 'cyl'
plt.subplot(2,1,1)
sns.stripplot(x='cylinders', y='horsepower', data=auto)

# Make the strip plot again using jitter and a smaller point size
plt.subplot(2,1,2)
sns.stripplot(x='cylinders', y='horsepower', data=auto, jitter=True, size =3)

# Display the plot
plt.show()

# %% [markdown]
# ### Swarm Plot

# %%
sns.swarmplot(x='cylinders',y='horsepower',data=auto)

# %%
sns.swarmplot(x='cylinders',y='horsepower',data=auto,hue='origin')

# %%
sns.swarmplot(y='cylinders',x='horsepower',data=auto,hue='origin',orient='h')

# %% [markdown]
# ### Violin plots

# %%
sns.violinplot(x='cylinders',y='horsepower',data=auto,inner=None,color='lightgray')
sns.stripplot(x='cylinders',y='horsepower',data=auto,jitter=True)

# %% [markdown]
# ## Multivariate Distributions

# %% [markdown]
# * Joint Plots
# * Pairplots
# * Heatmaps

# %%
import seaborn as sns
import pandas as pd 
import matplotlib.pyplot as plt

# %%
auto=pd.read_csv('auto-mpg.csv',na_values='?')

# %%
sns.pairplot(auto)
