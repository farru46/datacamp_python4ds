# %%
import pandas as pd
import numpy as np
import re

# %%
filename = "/Users/actify/Documents/Projects/digvijay_cement/dc_data-input/1 DC Kiln/DC Kiln 2016/daily_kiln_log_sched_20160101_a_day_daily.xls"

# %%
data=pd.read_excel(filename ,skiprows=12, header=None)

# %%
def read_and_transform_file(filename):
    
     
    df = pd.read_excel(filename, skiprows=6, header=None,nrows=30)
    
#      Extracting the column names
    col_names=df.iloc[0:5, :].ffill(axis=1).T
    col_names = col_names.replace(np.nan, '', regex=True)
    col_names = col_names[0] + "_" + col_names[1] + "_" + col_names[2] +"_" + col_names[3] + "_" + col_names[4]
    col_names[0]='TIME'
    
#     Extracting the data
    df=df.iloc[6:,:]
    
#     Setting column names
    df.columns=col_names    
    
#     Adding date column
    dt=re.search("([0-9]{4}[0-9]{2}[0-9]{2})", filename).group(1)
    
    df['Date'] = dt
    df['TIME'] = pd.to_datetime(df['Date'] + ' ' + df['TIME'], format = "%Y%m%d %H.%M")
#     date_col = pd.to_datetime(df['Date'], infer_datetime_format = True)
    df.set_index('TIME', drop = True, inplace=True)
    df.drop(['Date'], inplace=True, axis =1)
    df=df.astype('float64')
    df['Date'] = pd.to_datetime(dt)
    
#     df['TIME']=time
    
    
    return df

# %%
df=read_and_transform_file(filename)
df.head()
# Out:
#                      TOTAL FEED____T / Hr.  COAL_KILN ST.___T / Hr.  \
# TIME
# 2016-01-01 00:00:00             202.114838                 0.393243
# 2016-01-01 01:00:00             202.074539                 0.137712
# 2016-01-01 02:00:00             202.096024                 0.024839
# 2016-01-01 03:00:00             202.097290                 0.421759
# 2016-01-01 04:00:00             202.104874                 0.036769
#
#                      COAL_CAL. ST.___T / Hr.  KILN HOOD_DRFT___mmWg  \
# TIME
# 2016-01-01 00:00:00                -0.036237              -0.321139
# 2016-01-01 01:00:00                -0.037085              -0.334760
# 2016-01-01 02:00:00                -0.036813              -0.331994
# 2016-01-01 03:00:00                -0.038170              -0.406152
# 2016-01-01 04:00:00                -0.037159              -0.082405
#
#                      KILN HOOD_SEC._AIR_TMP_OC  B.Z. TEMP_SEC._AIR_TMP_0C  \
# TIME
# 2016-01-01 00:00:00                 423.645966                        NaN
# 2016-01-01 01:00:00                 417.690460                        NaN
# 2016-01-01 02:00:00                 438.170807                        NaN
# 2016-01-01 03:00:00                 392.669525                        NaN
# 2016-01-01 04:00:00                 413.512360                        NaN
#
#                      KILN_SPD_AIR_TMP_RPM  KILN_PWR_AIR_TMP_KW  \
# TIME
# 2016-01-01 00:00:00              -0.01094             0.747253
# 2016-01-01 01:00:00              -0.01094             0.747253
# 2016-01-01 02:00:00              -0.01094             0.747253
# 2016-01-01 03:00:00              -0.01094             0.747253
# 2016-01-01 04:00:00              -0.01094             0.747253
#
#                      KILN_TRQ_AIR_TMP_N  KILN I/L_PRESS_AIR_TMP_mmWg  ...  \
# TIME                                                                  ...
# 2016-01-01 00:00:00           12.248096                    -0.305691  ...
# 2016-01-01 01:00:00           12.248096                    -0.444140  ...
# 2016-01-01 02:00:00           12.248096                    -0.366063  ...
# 2016-01-01 03:00:00           12.248096                    -0.339337  ...
# 2016-01-01 04:00:00           12.248096                    -0.947158  ...
#
#                      KILN STRING TEMP. & DRAFT_CYCLONE  II_GAS_BOT_OC  \
# TIME
# 2016-01-01 00:00:00                                        343.456818
# 2016-01-01 01:00:00                                        353.363739
# 2016-01-01 02:00:00                                        361.227539
# 2016-01-01 03:00:00                                        379.591492
# 2016-01-01 04:00:00                                        395.075134
#
#                      KILN STRING TEMP. & DRAFT_CYCLONE  II_DRFT_BOT_mmWg  \
# TIME
# 2016-01-01 00:00:00                                          -3.445259
# 2016-01-01 01:00:00                                          -3.927147
# 2016-01-01 02:00:00                                          -4.031543
# 2016-01-01 03:00:00                                          -4.703706
# 2016-01-01 04:00:00                                          -5.940782
#
#                      KILN STRING TEMP. & DRAFT_TWIN CYC._DRFT_I_mmWg  \
# TIME
# 2016-01-01 00:00:00                                        -3.989282
# 2016-01-01 01:00:00                                        -5.088862
# 2016-01-01 02:00:00                                        -7.628544
# 2016-01-01 03:00:00                                        -8.678606
# 2016-01-01 04:00:00                                        -9.884008
#
#                      KILN STRING TEMP. & DRAFT_TWIN CYC._DRFT_II_mmWg  \
# TIME
# 2016-01-01 00:00:00                                         -4.981008
# 2016-01-01 01:00:00                                         -5.563694
# 2016-01-01 02:00:00                                         -6.030390
# 2016-01-01 03:00:00                                         -6.638176
# 2016-01-01 04:00:00                                         -7.912764
#
#                      AFTER P. H._BFR WTR SPR_DRFT_II_0C  \
# TIME
# 2016-01-01 00:00:00                          274.361237
# 2016-01-01 01:00:00                          286.266724
# 2016-01-01 02:00:00                          293.701355
# 2016-01-01 03:00:00                          306.638794
# 2016-01-01 04:00:00                          320.173431
#
#                      AFTER P. H._AFT WTR SPR_DRFT_II_0C  \
# TIME
# 2016-01-01 00:00:00                          176.547211
# 2016-01-01 01:00:00                          185.005585
# 2016-01-01 02:00:00                          187.956985
# 2016-01-01 03:00:00                          195.434753
# 2016-01-01 04:00:00                          203.510971
#
#                      AFTER P. H._BFR WTR SPR_DRFT_II_mmWg  \
# TIME
# 2016-01-01 00:00:00                             -6.361760
# 2016-01-01 01:00:00                             -7.163548
# 2016-01-01 02:00:00                             -7.430808
# 2016-01-01 03:00:00                             -8.157981
# 2016-01-01 04:00:00                             -9.380685
#
#                      AFTER P. H._AFT WTR SPR_DRFT_II_mmWg  \
# TIME
# 2016-01-01 00:00:00                             22.307352
# 2016-01-01 01:00:00                             22.460649
# 2016-01-01 02:00:00                             22.332447
# 2016-01-01 03:00:00                             22.425383
# 2016-01-01 04:00:00                             22.228331
#
#                      AFTER P. H._O2_DRFT_II_%       Date
# TIME
# 2016-01-01 00:00:00                 13.455415 2016-01-01
# 2016-01-01 01:00:00                 14.570502 2016-01-01
# 2016-01-01 02:00:00                 14.135745 2016-01-01
# 2016-01-01 03:00:00                 13.344450 2016-01-01
# 2016-01-01 04:00:00                 14.398628 2016-01-01
#
# [5 rows x 27 columns]

# %%
df.groupby('Date').agg(['mean', 'max', ''])
# Out:
#            TOTAL FEED____T / Hr.             COAL_KILN ST.___T / Hr.  \
#                              sum        mean                     sum
# Date
# 2016-01-01           3296.010361  137.333765               83.834385
#
#                      COAL_CAL. ST.___T / Hr.           KILN HOOD_DRFT___mmWg  \
#                 mean                     sum      mean                   sum
# Date
# 2016-01-01  3.493099              117.727637  4.905318              -34.4707
#
#                      KILN HOOD_SEC._AIR_TMP_OC              ...  \
#                 mean                       sum        mean  ...
# Date                                                        ...
# 2016-01-01 -1.436279              15345.333527  639.388897  ...
#
#            AFTER P. H._BFR WTR SPR_DRFT_II_0C              \
#                                           sum        mean
# Date
# 2016-01-01                        8950.603088  372.941795
#
#            AFTER P. H._AFT WTR SPR_DRFT_II_0C              \
#                                           sum        mean
# Date
# 2016-01-01                        7193.144623  299.714359
#
#            AFTER P. H._BFR WTR SPR_DRFT_II_mmWg              \
#                                             sum        mean
# Date
# 2016-01-01                          4898.511914  204.104663
#
#            AFTER P. H._AFT WTR SPR_DRFT_II_mmWg              \
#                                             sum        mean
# Date
# 2016-01-01                          5901.444124  245.893505
#
#            AFTER P. H._O2_DRFT_II_%
#                                 sum      mean
# Date
# 2016-01-01               205.352587  8.556358
#
# [1 rows x 52 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 24 entries, 2016-01-01 00:00:00 to 2016-01-01 23:00:00
# Data columns (total 27 columns):
# TOTAL FEED___                                      24 non-null float64
# COAL_KILN ST.__                                    24 non-null float64
# COAL_CAL. ST.__                                    24 non-null float64
# KILN HOOD_DRFT__                                   24 non-null float64
# KILN HOOD_SEC._AIR_TMP                             24 non-null float64
# B.Z. TEMP_SEC._AIR_TMP                             12 non-null float64
# KILN_SPD_AIR_TMP                                   24 non-null float64
# KILN_PWR_AIR_TMP                                   24 non-null float64
# KILN_TRQ_AIR_TMP                                   24 non-null float64
# KILN I/L_PRESS_AIR_TMP                             24 non-null float64
# KILN I/L_O2_AIR_TMP                                24 non-null float64
# KILN STRING TEMP. & DRAFT_CYCLONE  IV_GAS_TMP      24 non-null float64
# KILN STRING TEMP. & DRAFT_CYCLONE  IV_MT_TMP       24 non-null float64
# KILN STRING TEMP. & DRAFT_CYCLONE  IV_DRFT_BOT     24 non-null float64
# KILN STRING TEMP. & DRAFT_CYCLONE  IV_EX._BOT      24 non-null float64
# KILN STRING TEMP. & DRAFT_CYCLONE  III_GAS_BOT     24 non-null float64
# KILN STRING TEMP. & DRAFT_CYCLONE  III_DRFT_BOT    24 non-null float64
# KILN STRING TEMP. & DRAFT_CYCLONE  II_GAS_BOT      24 non-null float64
# KILN STRING TEMP. & DRAFT_CYCLONE  II_DRFT_BOT     24 non-null float64
# KILN STRING TEMP. & DRAFT_TWIN CYC._DRFT_I         24 non-null float64
# KILN STRING TEMP. & DRAFT_TWIN CYC._DRFT_II        24 non-null float64
# AFTER P. H._BFR WTR SPR_DRFT_II                    24 non-null float64
# AFTER P. H._AFT WTR SPR_DRFT_II                    24 non-null float64
# AFTER P. H._BFR WTR SPR_DRFT_II                    24 non-null float64
# AFTER P. H._AFT WTR SPR_DRFT_II                    24 non-null float64
# AFTER P. H._O2_DRFT_II                             24 non-null float64
# Date                                               24 non-null datetime64[ns]
# dtypes: datetime64[ns](1), float64(26)
# memory usage: 5.9 KB

# %%
df.shape
# Out:
# (24, 27)

# %%
df = pd.read_excel(filename, skiprows=6, header=None,nrows=30)

# %%
col_names=df.iloc[0:5, :].ffill(axis=1).T
col_names
# Out:
#                             0             1     2    3        4
# 0                        TIME           NaN   NaN  NaN      NaN
# 1                  TOTAL FEED           NaN   NaN  NaN  T / Hr.
# 2                        COAL      KILN ST.   NaN  NaN  T / Hr.
# 3                        COAL      CAL. ST.   NaN  NaN  T / Hr.
# 4                   KILN HOOD          DRFT   NaN  NaN     mmWg
# 5                   KILN HOOD          SEC.   AIR  TMP       OC
# 6                   B.Z. TEMP          SEC.   AIR  TMP       0C
# 7                        KILN           SPD   AIR  TMP      RPM
# 8                        KILN           PWR   AIR  TMP       KW
# 9                        KILN           TRQ   AIR  TMP        N
# 10                   KILN I/L         PRESS   AIR  TMP     mmWg
# 11                   KILN I/L            O2   AIR  TMP        %
# 12  KILN STRING TEMP. & DRAFT   CYCLONE  IV   GAS  TMP       OC
# 13  KILN STRING TEMP. & DRAFT   CYCLONE  IV    MT  TMP       OC
# 14  KILN STRING TEMP. & DRAFT   CYCLONE  IV  DRFT  BOT     mmWg
# 15  KILN STRING TEMP. & DRAFT   CYCLONE  IV   EX.  BOT     mmWg
# 16  KILN STRING TEMP. & DRAFT  CYCLONE  III   GAS  BOT       OC
# 17  KILN STRING TEMP. & DRAFT  CYCLONE  III  DRFT  BOT     mmWg
# 18  KILN STRING TEMP. & DRAFT   CYCLONE  II   GAS  BOT       OC
# 19  KILN STRING TEMP. & DRAFT   CYCLONE  II  DRFT  BOT     mmWg
# 20  KILN STRING TEMP. & DRAFT     TWIN CYC.  DRFT    I     mmWg
# 21  KILN STRING TEMP. & DRAFT     TWIN CYC.  DRFT   II     mmWg
# 22                AFTER P. H.   BFR WTR SPR  DRFT   II       0C
# 23                AFTER P. H.   AFT WTR SPR  DRFT   II       0C
# 24                AFTER P. H.   BFR WTR SPR  DRFT   II     mmWg
# 25                AFTER P. H.   AFT WTR SPR  DRFT   II     mmWg
# 26                AFTER P. H.            O2  DRFT   II        %

# %%
col_names = col_names.replace(np.nan, '', regex=True)
col_names
# Out:
#                             0             1     2    3        4
# 0                        TIME
# 1                  TOTAL FEED                           T / Hr.
# 2                        COAL      KILN ST.             T / Hr.
# 3                        COAL      CAL. ST.             T / Hr.
# 4                   KILN HOOD          DRFT                mmWg
# 5                   KILN HOOD          SEC.   AIR  TMP       OC
# 6                   B.Z. TEMP          SEC.   AIR  TMP       0C
# 7                        KILN           SPD   AIR  TMP      RPM
# 8                        KILN           PWR   AIR  TMP       KW
# 9                        KILN           TRQ   AIR  TMP        N
# 10                   KILN I/L         PRESS   AIR  TMP     mmWg
# 11                   KILN I/L            O2   AIR  TMP        %
# 12  KILN STRING TEMP. & DRAFT   CYCLONE  IV   GAS  TMP       OC
# 13  KILN STRING TEMP. & DRAFT   CYCLONE  IV    MT  TMP       OC
# 14  KILN STRING TEMP. & DRAFT   CYCLONE  IV  DRFT  BOT     mmWg
# 15  KILN STRING TEMP. & DRAFT   CYCLONE  IV   EX.  BOT     mmWg
# 16  KILN STRING TEMP. & DRAFT  CYCLONE  III   GAS  BOT       OC
# 17  KILN STRING TEMP. & DRAFT  CYCLONE  III  DRFT  BOT     mmWg
# 18  KILN STRING TEMP. & DRAFT   CYCLONE  II   GAS  BOT       OC
# 19  KILN STRING TEMP. & DRAFT   CYCLONE  II  DRFT  BOT     mmWg
# 20  KILN STRING TEMP. & DRAFT     TWIN CYC.  DRFT    I     mmWg
# 21  KILN STRING TEMP. & DRAFT     TWIN CYC.  DRFT   II     mmWg
# 22                AFTER P. H.   BFR WTR SPR  DRFT   II       0C
# 23                AFTER P. H.   AFT WTR SPR  DRFT   II       0C
# 24                AFTER P. H.   BFR WTR SPR  DRFT   II     mmWg
# 25                AFTER P. H.   AFT WTR SPR  DRFT   II     mmWg
# 26                AFTER P. H.            O2  DRFT   II        %

# %%
col_names = col_names[0] + "_" + col_names[1] + "_" + col_names[2] +"_" + col_names[3] + "_" + col_names[4]

# %%
col_names.str.endswith('_')
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# dtype: bool
