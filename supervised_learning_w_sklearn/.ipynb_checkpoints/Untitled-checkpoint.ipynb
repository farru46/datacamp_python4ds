# %%
import sys
sys.path.append("/Users/actify/Desktop/")

# %%
import pandas as pd

# %%
from utils import read_df
# import utils

# %%
df = read_df("/Users/actify/Documents/Projects/digvijay_cement/Master_Digvijay(Agg).csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-9b3f434254e9> in <module>
# ----> 1 df = utils.read_df("/Users/actify/Documents/Projects/digvijay_cement/Master_Digvijay(Agg).csv")
#
# ~/Desktop/utils.py in read_df(filename)
#       2
#       3 def read_df(filename):
# ----> 4     return pd.read_csv(filename)
#
# NameError: name 'pd' is not defined

# %%
df
# Out:
#             Date  TOTAL FEED____T / Hr._mean  TOTAL FEED____T / Hr._min  \
# 0     01-01-2016                  137.333765                  41.759750
# 1     02-01-2016                  214.359543                 207.048706
# 2     03-01-2016                  217.291737                 217.217056
# 3     04-01-2016                  216.700105                 203.860626
# 4     05-01-2016                  114.085495                  12.751905
# ...          ...                         ...                        ...
# 1220  25-11-2019                  205.637649                  93.778652
# 1221  26-11-2019                  201.960710                 105.822737
# 1222  27-11-2019                   34.370975                   0.000000
# 1223  28-11-2019                    0.000000                   0.000000
# 1224  29-11-2019                    5.325968                   0.000000
#
#       TOTAL FEED____T / Hr._max  TOTAL FEED____T / Hr._std  \
# ...
