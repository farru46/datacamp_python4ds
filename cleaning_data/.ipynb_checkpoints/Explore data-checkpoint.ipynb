# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
pd.options.display.max_rows = 999

# %% [markdown]
# # Reading the data

# %%
df=pd.read_csv("../datasets/job_applications_data_NY.csv")

# %%
df.head()
# Out:
#        Job #  Doc #        Borough       House #                       Street Name   Block   Lot      Bin # Job Type Job Status                         Job Status Descrp Latest Action Date Building Type Community - Board  Cluster Landmarked Adult Estab Loft Board City Owned Little e  PC Filed eFiling Filed Plumbing Mechanical Boiler Fuel Burning Fuel Storage Standpipe Sprinkler Fire Alarm Equipment Fire Suppression Curb Cut Other Other Description Applicant's First Name           Applicant's Last Name Applicant Professional Title Applicant License # Professional Cert Pre- Filing Date        Paid  Fully Paid Assigned    Approved Fully Permitted Initial Cost Total Est. Fee Fee Status  Existing Zoning Sqft  Proposed Zoning Sqft Horizontal Enlrgmt Vertical Enlrgmt  Enlargement SQ Footage  Street Frontage  ExistingNo. of Stories  Proposed No. of Stories  Existing Height  Proposed Height Existing Dwelling Units Proposed Dwelling Units Existing Occupancy Proposed Occupancy  \
# ...

# %%
df.shape
# Out:
# (4831, 82)

# %%
gapminder=pd.read_csv("../datasets/gapminder_r.csv")

# %%
gapminder.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
gapminder['continent'].value_counts(dropna=False)
# Out:
# Africa      624
# Asia        396
# Europe      360
# Americas    300
# Oceania      24
# Name: continent, dtype: int64

# %%
gapminder['year'].value_counts(dropna=False)
# Out:
# 2007    142
# 2002    142
# 1997    142
# 1992    142
# 1987    142
# 1982    142
# 1977    142
# 1972    142
# 1967    142
# 1962    142
# 1957    142
# 1952    142
# Name: year, dtype: int64

# %%
df.describe()
# Out:
#               Job #        Doc #         Block          Lot         Bin #  Cluster  PC Filed  Existing Zoning Sqft  Proposed Zoning Sqft  Enlargement SQ Footage  Street Frontage  ExistingNo. of Stories  Proposed No. of Stories  Existing Height  Proposed Height  Owner Type           Zip  Owner'sPhone #
# count  4.831000e+03  4831.000000   4830.000000  4830.000000  4.830000e+03      0.0       0.0          4.830000e+03          4.830000e+03             4830.000000      4830.000000             4830.000000              4830.000000      4830.000000      4830.000000         0.0  4.830000e+03    4.830000e+03
# mean   2.433060e+08     1.180708   2696.187578   612.057764  2.322690e+06      NaN       NaN          1.115631e+03          1.554843e+03               50.173913         2.786128                8.140994                 8.206418        95.621118        96.309317         NaN  1.414118e+06    5.018570e+09
# ...

# %% [markdown]
# # Frequency counts for categorical data

# %%
gapminder['country'].value_counts()
# Out:
# India                       12
# Brazil                      12
# Slovak Republic             12
# Indonesia                   12
# Libya                       12
# Czech Republic              12
# Mongolia                    12
# Korea, Dem. Rep.            12
# Myanmar                     12
# Pakistan                    12
# Israel                      12
# Korea, Rep.                 12
# Canada                      12
# Greece                      12
# Togo                        12
# Colombia                    12
# Nicaragua                   12
# Ethiopia                    12
# Botswana                    12
# Croatia                     12
# Trinidad and Tobago         12
# Jamaica                     12
# Sudan                       12
# New Zealand                 12
# Zimbabwe                    12
# Sweden                      12
# Bangladesh                  12
# Rwanda                      12
# Burundi                     12
# Congo, Rep.                 12
# ...

# %%
df['Borough'].value_counts(dropna=False)
# Out:
# MANHATTAN        2345
# BROOKLYN         1085
# QUEENS            810
# BRONX             381
# STATEN ISLAND     210
# Name: Borough, dtype: int64

# %%
df['State'].value_counts()
# Out:
# NY    4665
# NJ      88
# PA      25
# CA      10
# DC       6
# OH       5
# IL       4
# TX       4
# GA       3
# VA       3
# MA       3
# CO       3
# TN       2
# UT       2
# MD       2
# FL       2
# CT       1
# AZ       1
# NC       1
# Name: State, dtype: int64

# %% [markdown]
# # Visualizing individual variables

# %% [markdown]
# #### We start by plotting histogram for numeric values

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df['Existing Zoning Sqft'].describe()
# Out:
# count    4.830000e+03
# mean     1.115631e+03
# std      2.172757e+04
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      1.100533e+06
# Name: Existing Zoning Sqft, dtype: float64

# %%
df['Existing Zoning Sqft'].plot(kind='hist', logx=True, logy=True)
