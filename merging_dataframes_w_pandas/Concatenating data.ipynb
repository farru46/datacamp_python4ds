# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
# %matplotlib inline
import janitor

# %% [markdown]
# * s1.append(s2),
# * pd.concat([s1,s2] or [df1,df2], ignore_index=True/False),
# * reset_index()

# %%
bronze=pd.read_csv("../datasets/medals/bronze.csv").sort_values(by='Bronze',ascending=False).reset_index(drop=True).loc[0:5,:]
bronze
# Out:
#    NOC  Bronze
# 0  USA  1052.0
# 1  URS   584.0
# 2  GBR   505.0
# 3  FRA   475.0
# 4  GER   454.0
# 5  AUS   413.0

# %%
silver=pd.read_csv("../datasets/medals/silver.csv").sort_values(by='Silver',ascending=False).reset_index(drop=True).loc[0:5,:]
silver
# Out:
#    NOC  Silver
# 0  USA  1195.0
# 1  URS   627.0
# 2  GBR   591.0
# 3  FRA   461.0
# 4  ITA   394.0
# 5  AUS   369.0

# %%
kiln=pd.read_excel("/Users/actify/Documents/Projects/digvijay_cement/dc_data-input/1 DC Kiln/DC Kiln 2019/daily_kiln_log_sched_20190418_a_day_daily.xls", skiprows=5, header=None)

# %%
kiln.dropna(how='all')
# Out:
#        0           1         2         3          4        5          6   \
# 1    TIME  TOTAL FEED      COAL       NaN  KILN HOOD      NaN  B.Z. TEMP
# 2     NaN         NaN  KILN ST.  CAL. ST.       DRFT     SEC.        NaN
# 3     NaN         NaN       NaN       NaN        NaN      AIR        NaN
# 4     NaN         NaN       NaN       NaN        NaN      TMP        NaN
# 5     NaN     T / Hr.   T / Hr.   T / Hr.       mmWg       OC         0C
# 7   00.00     189.472   4.76808    12.418     -1.619  608.471     943.67
# 8   01.00     191.157   4.78132   11.9783   -1.68184  594.499        912
# 9   02.00     194.555   4.80851   10.5662   -1.71821   694.71    975.976
# 10  03.00     195.585   4.75796   10.6328   -1.70009  746.553    948.061
# 11  04.00     195.448   4.76184   10.7267    -1.6954  833.625    1087.63
# 12  05.00     199.373   4.76381   11.0994   -1.63955  827.711     1068.1
# 13  06.00     202.492   4.76567    11.402   -1.72236  805.733    1074.52
# ...

# %%
import janitor
import pandas as pd

# %%
df = pd.DataFrame({'Total Feed in kg' : [1,2,4]})

# %%
df.clean_names()
# Out:
#    total_feed_in_kg
# 0                 1
# 1                 2
# 2                 4

# %% [markdown]
# # Appending and Concatenating Dataframes

# %%
import glob
file_list=glob.glob("../datasets/namesbystate (1)/*.TXT")
file_list
# Out:
# ['../datasets/namesbystate (1)/AK.TXT',
#  '../datasets/namesbystate (1)/AL.TXT',
#  '../datasets/namesbystate (1)/AR.TXT',
#  '../datasets/namesbystate (1)/AZ.TXT',
#  '../datasets/namesbystate (1)/CA.TXT',
#  '../datasets/namesbystate (1)/CO.TXT',
#  '../datasets/namesbystate (1)/CT.TXT',
#  '../datasets/namesbystate (1)/DC.TXT',
#  '../datasets/namesbystate (1)/DE.TXT',
#  '../datasets/namesbystate (1)/FL.TXT',
#  '../datasets/namesbystate (1)/GA.TXT',
#  '../datasets/namesbystate (1)/HI.TXT',
#  '../datasets/namesbystate (1)/IA.TXT',
#  '../datasets/namesbystate (1)/ID.TXT',
#  '../datasets/namesbystate (1)/IL.TXT',
#  '../datasets/namesbystate (1)/IN.TXT',
#  '../datasets/namesbystate (1)/KS.TXT',
#  '../datasets/namesbystate (1)/KY.TXT',
#  '../datasets/namesbystate (1)/LA.TXT',
#  '../datasets/namesbystate (1)/MA.TXT',
#  '../datasets/namesbystate (1)/MD.TXT',
#  '../datasets/namesbystate (1)/ME.TXT',
#  '../datasets/namesbystate (1)/MI.TXT',
# ...

# %%
df_list=[pd.read_csv(x, names=['State Code', 'Sex', 'Year','Name', 'Occurrences']).clean_names() for x in file_list]
df_list[0]
# Out:
#       state_code sex  year      name  occurrences
# 0             AK   F  1910      Mary           14
# 1             AK   F  1910     Annie           12
# 2             AK   F  1910      Anna           10
# 3             AK   F  1910  Margaret            8
# 4             AK   F  1910     Helen            7
# ...          ...  ..   ...       ...          ...
# 28523         AK   M  2018      Theo            5
# 28524         AK   M  2018    Thorin            5
# 28525         AK   M  2018   Trenton            5
# 28526         AK   M  2018    Victor            5
# 28527         AK   M  2018      Zion            5
#
# [28528 rows x 5 columns]

# %%
master_df = pd.concat(df_list)

# %%
master_df.head()
# Out:
#   state_code sex  year      name  occurrences
# 0         AK   F  1910      Mary           14
# 1         AK   F  1910     Annie           12
# 2         AK   F  1910      Anna           10
# 3         AK   F  1910  Margaret            8
# 4         AK   F  1910     Helen            7

# %%
master_df.shape
# Out:
# (6028151, 5)

# %%
master_df.loc[0,:].head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-bb433f425b8e> in <module>
# ----> 1 master_df.loc[0,:].head()
#
# NameError: name 'master_df' is not defined

# %%
weather_max = pd.read_csv("../datasets/weather_max.csv", index_col='Month').clean_names()
weather_max
# Out:
#        max_temperaturef
# Month
# Jan                  68
# Apr                  89
# Jul                  91
# Oct                  84

# %%
weather_mean=pd.read_csv("../datasets/weather_mean.csv", index_col='Month').clean_names()
weather_mean
# Out:
#        mean_temperaturef
# Month
# Apr            53.100000
# Aug            70.000000
# Dec            34.935484
# Feb            28.714286
# Jan            32.354839
# Jul            72.870968
# Jun            70.133333
# Mar            35.000000
# May            62.612903
# Nov            39.800000
# Oct            55.451613
# Sep            63.766667

# %%
pd.concat([weather_max,weather_mean], axis='columns')
# Out:
# /Users/actify/environments/py_ds/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#      max_temperaturef  mean_temperaturef
# Apr              89.0          53.100000
# Aug               NaN          70.000000
# Dec               NaN          34.935484
# Feb               NaN          28.714286
# Jan              68.0          32.354839
# Jul              91.0          72.870968
# Jun               NaN          70.133333
# Mar               NaN          35.000000
# May               NaN          62.612903
# Nov               NaN          39.800000
# Oct              84.0          55.451613
# Sep               NaN          63.766667

# %%
medals=pd.read_csv("../datasets/Summer Olympic medallists 1896 to 2008 - ALL MEDALISTS.tsv", sep="\t", skiprows=4).clean_names()

# %%
medals.head()
# Out:
#      city  edition     sport discipline             athlete  noc gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         event event_gender   medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
medals=['bronze', 'silver', 'gold']
for medal in medals:
    # Create the file name: file_name
#     file_name = "%s_top5.csv" % medal
    file_name = f"{medal}_top5.csv"
    columns = ['Country', medal]
    print(file_name, columns)
# Out:
# bronze_top5.csv ['Country', 'bronze']
# silver_top5.csv ['Country', 'silver']
# gold_top5.csv ['Country', 'gold']

# %%
# Reading multiple files to build a dataframe

file_list = glob.glob("/Users/actify/Documents/Projects/digvijay_cement/dc_data-input/1 DC Kiln/DC Kiln 2019/*.xls")

# %%
file_list
# Out:
# ['/Users/actify/Documents/Projects/digvijay_cement/dc_data-input/1 DC Kiln/DC Kiln 2019/daily_kiln_log_sched_20190418_a_day_daily.xls',
#  '/Users/actify/Documents/Projects/digvijay_cement/dc_data-input/1 DC Kiln/DC Kiln 2019/daily_kiln_log_sched_20190419_a_day_daily.xls',
#  '/Users/actify/Documents/Projects/digvijay_cement/dc_data-input/1 DC Kiln/DC Kiln 2019/daily_kiln_log_sched_20190420_a_day_daily.xls',
#  '/Users/actify/Documents/Projects/digvijay_cement/dc_data-input/1 DC Kiln/DC Kiln 2019/daily_kiln_log_sched_20190421_a_day_daily.xls',
#  '/Users/actify/Documents/Projects/digvijay_cement/dc_data-input/1 DC Kiln/DC Kiln 2019/daily_kiln_log_sched_20190422_a_day_daily.xls',
#  '/Users/actify/Documents/Projects/digvijay_cement/dc_data-input/1 DC Kiln/DC Kiln 2019/daily_kiln_log_sched_20190423_a_day_daily.xls',
#  '/Users/actify/Documents/Projects/digvijay_cement/dc_data-input/1 DC Kiln/DC Kiln 2019/daily_kiln_log_sched_20190424_a_day_daily.xls',
# ...

# %%
df_list =[pd.read_excel(file) for file in file_list[1:100]]

# %%
final_df = pd.concat(df_list, axis= 'rows')

# %%
final_df.shape
# Out:
# (4653, 27)

# %%
# Out:
#                Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 0                     NaN        NaN        NaN
# 1                     NaN        NaN        NaN
# 2                     NaN        NaN        NaN
# 3  Friday, April 19, 2019        NaN        NaN
# 4                     NaN        NaN        NaN
#
#                                           Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0                                                NaN        NaN        NaN
# 1                                                ...        NaN        NaN
# 2                                                NaN        NaN        NaN
# 3                                                NaN        NaN        NaN
# 4                                                NaN        NaN        NaN
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 17 Unnamed: 18  \
# 0        NaN        NaN        NaN        NaN  ...         NaN         NaN
# ...

# %%
medals=pd.read_csv("../datasets/Summer Olympic medallists 1896 to 2008 - ALL MEDALISTS.tsv", sep="\t", skiprows=4).clean_names()

# %%
medals.head()
# Out:
#      city  edition     sport discipline             athlete  noc gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         event event_gender   medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
bronze_5=medals[medals['medal'] == 'Bronze'].iloc[0:5, :]
silver_5=medals[medals['medal'] == 'Silver'].iloc[0:5, :]
gold_5=medals[medals['medal'] == 'Gold'].iloc[0:5, :]

# %%
medals_=pd.concat([bronze_5,silver_5,gold_5], keys=['bronze','silver','gold'], axis='rows')
# medals_.set_index('noc')
# Out:
#        city  edition      sport discipline                athlete gender  \
# noc
# GRE  Athens     1896   Aquatics   Swimming      DRIVAS, Dimitrios    Men
# GRE  Athens     1896   Aquatics   Swimming  CHOROPHAS, Efstathios    Men
# GRE  Athens     1896   Aquatics   Swimming  CHOROPHAS, Efstathios    Men
# USA  Athens     1896  Athletics  Athletics          LANE, Francis    Men
# HUN  Athens     1896  Athletics  Athletics       SZOKOLYI, Alajos    Men
# AUT  Athens     1896   Aquatics   Swimming       HERSCHMANN, Otto    Men
# GRE  Athens     1896   Aquatics   Swimming     CHASAPIS, Spiridon    Men
# GRE  Athens     1896   Aquatics   Swimming       ANDREOU, Joannis    Men
# GRE  Athens     1896   Aquatics   Swimming      PEPANOS, Antonios    Men
# GER  Athens     1896  Athletics  Athletics         HOFMANN, Fritz    Men
# HUN  Athens     1896   Aquatics   Swimming          HAJOS, Alfred    Men
# GRE  Athens     1896   Aquatics   Swimming     MALOKINIS, Ioannis    Men
# ...

# %%
medals_.sort_index(level=0)
# Out:
#              city  edition      sport discipline                athlete  noc  \
# bronze 2   Athens     1896   Aquatics   Swimming      DRIVAS, Dimitrios  GRE
#        5   Athens     1896   Aquatics   Swimming  CHOROPHAS, Efstathios  GRE
#        8   Athens     1896   Aquatics   Swimming  CHOROPHAS, Efstathios  GRE
#        11  Athens     1896  Athletics  Athletics          LANE, Francis  USA
#        12  Athens     1896  Athletics  Athletics       SZOKOLYI, Alajos  HUN
# gold   0   Athens     1896   Aquatics   Swimming          HAJOS, Alfred  HUN
#        3   Athens     1896   Aquatics   Swimming     MALOKINIS, Ioannis  GRE
#        6   Athens     1896   Aquatics   Swimming          HAJOS, Alfred  HUN
#        9   Athens     1896   Aquatics   Swimming          NEUMANN, Paul  AUT
#        13  Athens     1896  Athletics  Athletics          BURKE, Thomas  USA
# silver 1   Athens     1896   Aquatics   Swimming       HERSCHMANN, Otto  AUT
# ...

# %%
medals_.loc[('bronze',12)]
# Out:
# city                      Athens
# edition                     1896
# sport                  Athletics
# discipline             Athletics
# athlete         SZOKOLYI, Alajos
# noc                          HUN
# gender                       Men
# event                       100m
# event_gender                   M
# medal                     Bronze
# Name: (bronze, 12), dtype: object

# %%
# Sort the entries of medals: medals_sorted
medals_sorted = medals.sort_index(level=0)

# Print the number of Bronze medals won by Germany
print(medals_sorted.loc[('bronze','Germany')])

# Print data about silver medals
print(medals_sorted.loc['silver'])

# Create alias for pd.IndexSlice: idx
idx = pd.IndexSlice

# Print all the data on medals won by the United Kingdom
print(medals_sorted.loc[idx[:,'United Kingdom'], :])

# %%
# Concatenate dataframes: february
february = pd.concat(dataframes, keys=['Hardware', 'Software', 'Service'], axis='columns')

# Print february.info()
print(february.info())

# Assign pd.IndexSlice: idx
idx = pd.IndexSlice

# Create the slice: slice_2_8
slice_2_8 = february.loc['Feb 2, 2015':'Feb 8, 2015', idx[:, 'Company']]

# Print slice_2_8
print(slice_2_8)

# %% [markdown]
# # Outer and Inner Joins

# %%
import pandas as pd
import numpy as np

# %%
bronze=pd.read_csv("../datasets/bronze.csv", index_col='Country')
silver=pd.read_csv("../datasets/silver.csv", index_col='Country')
gold=pd.read_csv("../datasets/gold.csv", index_col='Country')

# %%
bronze
# Out:
#                 Total
# Country
# United States    1052
# Soviet Union      584
# United Kingdom    505
# France            475
# Germany           454

# %%
silver
# Out:
#                 Total
# Country
# United States    1195
# Soviet Union      627
# United Kingdom    591
# France            461
# Italy             394

# %%
gold
# Out:
#                 Total
# Country
# United States    2088
# Soviet Union      838
# United Kingdom    498
# Italy             460
# Germany           407

# %%
medal_list = [bronze, silver, gold]
pd.concat(medal_list, axis='columns', keys=['bronze', 'silver', 'gold'], join='inner')
# Out:
#                bronze silver  gold
#                 Total  Total Total
# Country
# United States    1052   1195  2088
# Soviet Union      584    627   838
# United Kingdom    505    591   498
